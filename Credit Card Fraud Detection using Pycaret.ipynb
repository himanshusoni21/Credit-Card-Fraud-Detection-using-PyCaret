# %%
import numpy as np
import pandas as pd
from pycaret.classification import *

# %%
data = pd.read_csv('E:\itsstudytym\Python Project\ML Notebook Sessions\Credit Card Fraud Detection using Pycaret\creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
len(data[data['Class']==1]) # No of Fraud Transaction
# Out:
# 492

# %%
len(data[data['Class']==0]) # No of Normal Transaction
# Out:
# 284315

# %%
# This is highly imbalanced dataset

# %% [markdown]
# ### Logistic Regression

# %%
from pycaret.classification import *
model = setup(data = data,target = 'Class')
lr = create_model('lr')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9986  0.9170  0.8333  0.5556  0.6667  0.6660
# 1       0.9988  0.9730  0.7500  0.6207  0.6792  0.6786
# 2       0.9988  0.9275  0.5833  0.6667  0.6222  0.6216
# 3       0.9992  0.9411  0.8000  0.7692  0.7843  0.7839
# 4       0.9988  0.9384  0.6667  0.6400  0.6531  0.6525
# 5       0.9990  0.9037  0.7917  0.6786  0.7308  0.7303
# 6       0.9994  0.9526  0.7917  0.8636  0.8261  0.8258
# 7       0.9991  0.9041  0.7083  0.7727  0.7391  0.7387
# 8       0.9994  0.8675  0.6667  0.9412  0.7805  0.7802
# 9       0.9990  0.8907  0.5833  0.7778  0.6667  0.6662
# Mean    0.9990  0.9216  0.7175  0.7286  0.7149  0.7144
# SD      0.0003  0.0297  0.0858  0.1119  0.0638  0.0639

# %% [markdown]
# ### K-Nearest Neighbor

# %%
model = setup(data = data,target ='Class')
knn = create_model('knn')
# Out:
#       Accuracy     AUC  Recall  Prec.     F1   Kappa
# 0       0.9983  0.5190  0.0000    0.0  0.000  0.0000
# 1       0.9981  0.5818  0.0000    0.0  0.000 -0.0003
# 2       0.9983  0.5195  0.0000    0.0  0.000  0.0000
# 3       0.9982  0.6382  0.0000    0.0  0.000  0.0000
# 4       0.9983  0.5812  0.0000    0.0  0.000  0.0000
# 5       0.9983  0.5816  0.0000    0.0  0.000  0.0000
# 6       0.9983  0.5817  0.0000    0.0  0.000  0.0000
# 7       0.9982  0.5819  0.0000    0.0  0.000 -0.0001
# 8       0.9983  0.5812  0.0000    0.0  0.000  0.0000
# 9       0.9984  0.6441  0.0417    1.0  0.080  0.0799
# Mean    0.9983  0.5810  0.0042    0.1  0.008  0.0079
# SD      0.0001  0.0386  0.0125    0.3  0.024  0.0240

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_4d547978_8a04_11ea_8258_4cbb582ce06a th {
#           text-align: left;
#     }    #T_4d547978_8a04_11ea_8258_4cbb582ce06arow0_col0 {
#             text-align:  left;
#         }    #T_4d547978_8a04_11ea_8258_4cbb582ce06arow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_4d547978_8a04_11ea_8258_4cbb582ce06arow0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_4d547978_8a04_11ea_8258_4cbb582ce06arow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_4d547978_8a04_11ea_8258_4cbb582ce06arow0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_4d547978_8a04_11ea_8258_4cbb582ce06arow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_4d547978_8a04_11ea_8258_4cbb582ce06arow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_4d547978_8a04_11ea_8258_4cbb582ce06arow1_col0 {
# ...

# %% [markdown]
# ### Summary

# %% [markdown]
# As we have seen that multiple classification algorithms are modeled over imbalanced dataset and CatBoost Classifier, Extra Tree Classifier ,Extreme Gradient Boosting algorithms performs better

# %% [markdown]
# ### CatBoost Classification Algorithm

# %%
model = setup(data = data,target ='Class')
cat = create_model('catboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9993  0.9540  0.6923  0.9000  0.7826  0.7823
# 1       0.9997  0.9853  0.8462  1.0000  0.9167  0.9165
# 2       0.9997  0.9994  0.8462  0.9565  0.8980  0.8978
# 3       0.9997  0.9967  0.9200  0.9200  0.9200  0.9199
# 4       0.9996  0.9868  0.7600  1.0000  0.8636  0.8634
# 5       0.9995  0.9397  0.7692  0.9524  0.8511  0.8508
# 6       0.9997  0.9678  0.8462  0.9565  0.8980  0.8978
# 7       0.9995  0.9792  0.7692  0.9524  0.8511  0.8508
# 8       0.9991  0.9918  0.6154  0.8421  0.7111  0.7107
# 9       0.9993  0.9590  0.6923  0.9000  0.7826  0.7823
# Mean    0.9995  0.9760  0.7757  0.9380  0.8475  0.8472
# SD      0.0002  0.0190  0.0870  0.0460  0.0651  0.0652

# %% [markdown]
# ### Extra Tree Classsifier

# %%
model = setup(data = data,target ='Class')
cat = create_model('et')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9998  0.9605  0.8846  1.0000  0.9388  0.9387
# 1       0.9998  0.9604  0.8846  1.0000  0.9388  0.9387
# 2       0.9992  0.9397  0.6923  0.8182  0.7500  0.7496
# 3       0.9997  0.9992  0.8400  0.9545  0.8936  0.8935
# 4       0.9997  0.9584  0.8000  1.0000  0.8889  0.8887
# 5       0.9994  0.9596  0.6923  0.9474  0.8000  0.7997
# 6       0.9997  0.9407  0.8462  1.0000  0.9167  0.9165
# 7       0.9991  0.8607  0.5769  0.8824  0.6977  0.6973
# 8       0.9993  0.9199  0.6538  0.8947  0.7556  0.7552
# 9       0.9994  0.9785  0.7308  0.9048  0.8085  0.8082
# Mean    0.9995  0.9478  0.7602  0.9402  0.8388  0.8386
# SD      0.0002  0.0356  0.1006  0.0601  0.0829  0.0830

# %%
plot_model(cat,plot='confusion_matrix')

# %%
plot_model(cat,plot='class_report')
